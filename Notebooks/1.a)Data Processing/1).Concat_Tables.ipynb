# %% [markdown]
# ### This notebook fetches a collection of pre-processed csv files and concatenates them together into one larger csv file, ready for feature engineering.

# %%
from google.cloud import bigquery
import pandas as pd

# Initialize client (will use credentials from your environment)
client = bigquery.Client(project='cyclemore')

# Verify it's working
print(f"✅ Connected to project: {client.project}")

# List tables to see what you have
tables = list(client.list_tables("cycling_routes"))
print("\n📊 Available tables:")
for table in tables:
    print(f"  - {table.table_id}")
# Out:
# ✅ Connected to project: cyclemore
#
# 📊 Available tables:
#   - Alps
#   - Costa_Brava
#   - County_Kerry
#   - Dolomites
#   - Fjords
#   - Mallorca
#   - Munich
#   - UK1
#   - UK2_Data
#   - UK3
#   - UK4
#   - UK_5
#   - amsterdam
#   - belgium
#   - eastcoastus
#   - lille
#   - netherlands
#   - provence
#   - tile_esp_a_northwest
#   - tile_ita_b_east
#   - tile_ita_sicilia
#   - tile_ita_west

# %%
from google.cloud import bigquery
import pandas as pd

client = bigquery.Client(project='cyclemore')

# List all your UK tables
tables = ['Alps','Costa_Brava','County_Kerry','Dolomites','Fjords','Mallorca','Munich', 'UK1', 'UK2_Data', 'UK3', 'UK4', 'UK_5','amsterdam','belgium','eastcoastus','lille','netherlands','provence']  # Adjust based on what tables you saw above

dataframes = []

for table_name in tables:
    query = f"SELECT * FROM `cyclemore.cycling_routes.{table_name}`"

    try:
        df = client.query(query).to_dataframe()
        df['region'] = table_name  # Add region column
        dataframes.append(df)
        print(f"✅ Fetched {table_name}: {len(df)} routes, {len(df.columns)} columns")
    except Exception as e:
        print(f"❌ Error fetching {table_name}: {e}")

# Combine all dataframes
if dataframes:
    all_routes = pd.concat(dataframes, ignore_index=True)

    # Remove duplicates by route ID
    print(f"\nBefore deduplication: {len(all_routes)} routes")
    all_routes = all_routes.drop_duplicates(subset=['id'], keep='first')
    print(f"After deduplication: {len(all_routes)} routes")

    # Save combined file
    all_routes.to_csv('All_Routes_Combined.csv', index=False)
    print(f"\n💾 Saved to All_Routes_Combined.csv")

    # View
    display(all_routes.head())
    print(f"\nFinal shape: {all_routes.shape}")
# Out:
# /Users/eugeneleach/.pyenv/versions/3.12.9/envs/cyclemore/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# ✅ Fetched Alps: 1000 routes, 13 columns
# /Users/eugeneleach/.pyenv/versions/3.12.9/envs/cyclemore/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# ✅ Fetched Costa_Brava: 91 routes, 13 columns
# /Users/eugeneleach/.pyenv/versions/3.12.9/envs/cyclemore/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# ✅ Fetched County_Kerry: 149 routes, 13 columns
# /Users/eugeneleach/.pyenv/versions/3.12.9/envs/cyclemore/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# ✅ Fetched Dolomites: 149 routes, 13 columns
# /Users/eugeneleach/.pyenv/versions/3.12.9/envs/cyclemore/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# ✅ Fetched Fjords: 9 routes, 13 columns
# /Users/eugeneleach/.pyenv/versions/3.12.9/envs/cyclemore/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# ✅ Fetched Mallorca: 35 routes, 13 columns
# /Users/eugeneleach/.pyenv/versions/3.12.9/envs/cyclemore/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# ✅ Fetched Munich: 1693 routes, 13 columns
# /Users/eugeneleach/.pyenv/versions/3.12.9/envs/cyclemore/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# ✅ Fetched UK1: 1998 routes, 13 columns
# /Users/eugeneleach/.pyenv/versions/3.12.9/envs/cyclemore/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# ✅ Fetched UK2_Data: 1999 routes, 13 columns
# /Users/eugeneleach/.pyenv/versions/3.12.9/envs/cyclemore/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# ✅ Fetched UK3: 1 routes, 13 columns
# /Users/eugeneleach/.pyenv/versions/3.12.9/envs/cyclemore/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# ✅ Fetched UK4: 1996 routes, 13 columns
# /Users/eugeneleach/.pyenv/versions/3.12.9/envs/cyclemore/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# ✅ Fetched UK_5: 1999 routes, 13 columns
# /Users/eugeneleach/.pyenv/versions/3.12.9/envs/cyclemore/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# ✅ Fetched amsterdam: 2 routes, 12 columns
# /Users/eugeneleach/.pyenv/versions/3.12.9/envs/cyclemore/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# ✅ Fetched belgium: 3875 routes, 12 columns
# /Users/eugeneleach/.pyenv/versions/3.12.9/envs/cyclemore/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# ✅ Fetched eastcoastus: 1997 routes, 12 columns
# /Users/eugeneleach/.pyenv/versions/3.12.9/envs/cyclemore/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# ✅ Fetched lille: 106 routes, 12 columns
# /Users/eugeneleach/.pyenv/versions/3.12.9/envs/cyclemore/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# ✅ Fetched netherlands: 3289 routes, 12 columns
# /Users/eugeneleach/.pyenv/versions/3.12.9/envs/cyclemore/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# ✅ Fetched provence: 523 routes, 13 columns
#
# Before deduplication: 20911 routes
# After deduplication: 19151 routes
#
# 💾 Saved to All_Routes_Combined.csv
#          id                       name  distance_m  duration_s  ascent_m  \
# 0   6101627  Ciclopedonale Lago Ghirla      1885.5       377.1    [51.8]
# 1  10187640    Tour du Léman - Étape 4      4138.4       827.6   [164.5]
# 2  12509770          La Madeleine Nord     24714.5      4942.9  [2182.8]
# 3  15361105              Unnamed route       984.9       197.0    [14.5]
# 4  15630528              Unnamed route      1662.8       332.5    [31.1]
#
#   descent_m  steps  turns                                            surface  \
# 0    [93.8]      2      0             [[0, 37, 3], [37, 38, 0], [38, 62, 3]]
# 1   [173.5]      2      0                                      [[0, 118, 3]]
# 2   [670.8]      2      0  [[0, 525, 3], [525, 553, 0], [553, 595, 3], [5...
# 3    [21.5]      2      0                                       [[0, 30, 3]]
# 4     [9.1]      2      0                                       [[0, 49, 3]]
#
#                      waytype    waycategory  \
# 0  [[0, 38, 6], [38, 62, 2]]   [[0, 62, 0]]
# 1              [[0, 118, 1]]  [[0, 118, 0]]
# 2              [[0, 897, 2]]  [[0, 897, 0]]
# 3               [[0, 30, 3]]   [[0, 30, 0]]
# 4               [[0, 49, 2]]   [[0, 49, 0]]
#
#                                            steepness region
# 0  [[0, 7, -4], [7, 33, 1], [33, 39, -2], [39, 41...   Alps
# 1  [[0, 47, 1], [47, 67, -1], [67, 78, 2], [78, 8...   Alps
# 2  [[0, 2, 5], [2, 6, -3], [6, 7, 5], [7, 17, 4],...   Alps
# 3                                       [[0, 30, 0]]   Alps
# 4                                       [[0, 49, 1]]   Alps
# Final shape: (19151, 13)

# %% [markdown]
# ## Extracting the Coordinates

# %%
import requests
import json

# %%
# Overpass API endpoint
url = "https://maps.mail.ru/osm/tools/overpass/api/interpreter"

# %%
# Example query: All cycling routes in Europe (bicycle routes)
#-----------------------------------------------CHANGE COORDS HERE--------------------------------------#
query = """
[out:json][timeout:900];
(
  relation["route"="bicycle"](42.98, 4.2283, 45.16, 7.7189);
);
out geom;
"""
#-----------------------------------------------CHANGE COORDS HERE--------------------------------------#

# %%
# Make the request
response = requests.get(url, params={'data': query})

# %%
# Check success
if response.status_code == 200:
    data = response.json()
    print("✅ Success:", len(data['elements']), "routes found")
else:
    print("❌ Error:", response.status_code)
# Out:
# ✅ Success: 525 routes found

# %%
# Save response to file
#-----------------------------------------------CHANGE FILE NAME HERE--------------------------------------#
with open("Turbo_coords_provence.json", "w") as f:
    json.dump(data, f)
#-----------------------------------------------CHANGE FILE NAME HERE--------------------------------------#

# %%
import pandas as pd

# Create empty list to store results
routes_summary = []

# Loop through each route in the dataset
for route in data['elements']:
    if route['type'] != 'relation':
        continue  # skip non-route elements

    coords = []
    for member in route.get('members', []):
        if 'geometry' in member:
            segment_coords = [(pt['lon'], pt['lat']) for pt in member['geometry']]
            coords.extend(segment_coords)

    if coords:
        start_coord = coords[0]
        end_coord = coords[-1]
        routes_summary.append({
            'id': route.get('id'),
            'name': route.get('tags', {}).get('name', 'Unnamed route'),
            'start_lon': start_coord[0],
            'start_lat': start_coord[1],
            'end_lon': end_coord[0],
            'end_lat': end_coord[1],
            'num_points': len(coords)
        })

# %%
# Convert results to DataFrame
routes_df = pd.DataFrame(routes_summary)

# %%
routes_df.to_csv("turbo_start_end_coords_provence.csv", index=False)

# %%
routes_df
# Out:
#            id                                     name  start_lon  start_lat  \
# 0      168466                   Boucles du 13 Camargue   4.670930  43.514253
# 1      168472      Boucles du 13 - La Chaîne des Côtes   5.393765  43.685059
# 2      168474           Boucles du 13 - Saintes Maries   4.429896  43.499538
# 3      168475  Les boucles du 13 - Autour de Silvacane   5.186004  43.731102
# 4      168476            D’Arles à l’étang du Vaccarès   4.627061  43.675217
# ..        ...                                      ...        ...        ...
# 520  19816737           Vallées, châtaignes et volcans   4.358189  44.717815
# 521  19824619          Uzès à Saint-Quentin-la-Poterie   4.414556  44.027059
# 522  19849376                                      V65   5.251022  43.368071
# 523  19849377                                      V65   5.092375  43.333177
# 524  19849545                                      V65   5.194809  43.355993
#
#       end_lon    end_lat  num_points
# 0    4.702068  43.464042         533
# 1    5.394779  43.687317         857
# 2    4.429896  43.499538         646
# 3    5.241505  43.728157        1175
# 4    4.626507  43.675139        1388
# ..        ...        ...         ...
# 520  4.386783  44.717057        1253
# 521  4.438144  44.042723         150
# 522  5.251022  43.368071          31
# 523  5.103856  43.329831         115
# 524  5.189754  43.355678          26
#
# [525 rows x 7 columns]

# %% [markdown]
# # Extracting the features UK First 2,000

# %%
import os

# %%
AK = os.environ["AK"]

# %%
import openrouteservice
import pandas as pd
import json
import time
import os

# %%
# Initialize client
client = openrouteservice.Client(key=AK)  # Replace AK with your ORS API key

# %%
results = []
save_interval = 10

# %%
#-----------------------------------------------CHANGE FILE NAME HERE--------------------------------------#
save_path = "ors_Features_Provence.json"
#-----------------------------------------------CHANGE FILE NAME HERE--------------------------------------#

# %%
test_df = routes_df.iloc[0:1]

# %%
# Folder to save raw API responses
raw_dir = "raw_ors_responses_Provence_test"
os.makedirs(raw_dir, exist_ok=True)

for i, row in test_df.iterrows():
    start = [row['start_lon'], row['start_lat']]
    end = [row['end_lon'], row['end_lat']]

    try:
        # --- Call ORS API ---
        route = client.directions(
            coordinates=[start, end],
            profile='cycling-regular',
            format='geojson',
            elevation=True,
            extra_info=['surface', 'waytype', 'waycategory', 'steepness']
        )

        # --- Save JSON response ---
        raw_filename = f"{raw_dir}/route_{row['id']}.json"
        with open(raw_filename, "w") as f:
            json.dump(route, f, indent=2)

        print(f"✅ Saved route {row['id']} ({i+1}/{len(test_df)})")
        time.sleep(1.5)  # rate limit protection

    except Exception as e:
        print(f"❌ Error on route {row['id']}: {e}")
        continue
# Out:
# ✅ Saved route 168466 (1/1)

# %%
import json
import os
import pandas as pd

raw_dir = "raw_ors_responses_Provence_test"
results = []

# Loop through all JSON files
for filename in os.listdir(raw_dir):
    if not filename.endswith(".json"):
        continue

    filepath = os.path.join(raw_dir, filename)

    with open(filepath, "r") as f:
        route = json.load(f)

    try:
        props = route['features'][0]['properties']
        summary = props['summary']
        extras = props.get('extras', {})
        segments = props.get('segments', [{}])
        steps = segments[0].get('steps', [])

        # --- Extract features ---
        route_id = filename.replace("route_", "").replace(".json", "")
        distance = summary.get('distance')
        duration = summary.get('duration')
        ascent = props.get('ascent')
        descent = props.get('descent')
        turns = len([s for s in steps if s.get('type') in range(8)])
        num_steps = len(steps)

        results.append({
            'id': route_id,
            'distance_m': distance,
            'duration_s': duration,
            'ascent_m': ascent,
            'descent_m': descent,
            'turns': turns,
            'steps': num_steps,
            'surface': extras.get('surface', {}).get('values', []),
            'waytype': extras.get('waytype', {}).get('values', []),
            'waycategory': extras.get('waycategory', {}).get('values', []),
            'steepness': extras.get('steepness', {}).get('values', []),
        })

        print(f"✅ Parsed {filename}")

    except Exception as e:
        print(f"⚠️ Error parsing {filename}: {e}")

# --- Save to CSV ---
df = pd.DataFrame(results)
df.to_csv("processed_routes_Provence_test.csv", index=False)
print(f"✅ Saved {len(df)} processed routes to CSV")
# Out:
# ✅ Parsed route_168466.json
# ✅ Saved 1 processed routes to CSV

# %%
for i, row in test_df.iterrows():
    start = (row['start_lon'], row['start_lat'])
    end = (row['end_lon'], row['end_lat'])

    try:
        route = client.directions(
            coordinates=[start, end],
            profile='cycling-regular',
            format='geojson',
            elevation=True,
            instructions=True,
            extra_info=['surface', 'waytype', 'waycategory', 'steepness'],
        )



        # --- SAVE RAW ORS RESPONSE FOR DEBUGGING ---
        #-----------------------------------------------CHANGE FILE NAME HERE--------------------------------------#
        raw_dir = "raw_ors_responses_Provence"
        #-----------------------------------------------CHANGE FILE NAME HERE--------------------------------------#
        os.makedirs(raw_dir, exist_ok=True)

        raw_filename = f"{raw_dir}/route_{row['id']}.json"

        with open(raw_filename, "w") as raw_file:
            json.dump(route, raw_file, indent=2)
        # -------------------------------------------


        props = route['features'][0]['properties']
        summary = props['summary']
        extras = props.get('extras', {})
        segments = props['segments']
        steps = segments[0]['steps']
        turn_steps = [s for s in steps if s['type'] in {0,1,2,3,4,5,6,7}]
        turns = len(turn_steps)
        steps = len(steps)


        results.append({
            'id': row['id'],
            'name': row['name'],
            'distance_m': summary.get('distance'),
            'duration_s': summary.get('duration'),
            'ascent_m': [props['ascent']],
            'descent_m': [props['descent']],
            'steps': steps,
            'turns': turns,
            'surface': extras.get('surface', {}).get('values', []),
            'waytype': extras.get('waytype', {}).get('values', []),
            'waycategory': extras.get('waycategory', {}).get('values', []),
            'steepness': extras.get('steepness', {}).get('values', []),
        })

        print(f"✅ Route {i+1} processed successfully")
        time.sleep(1.5)  # rate-limit protection

        # Save partial file
        if (i + 1) % save_interval == 0:
            with open(save_path, "w") as f:
                json.dump(results, f, indent=2)
            print(f"💾 Saved partial results after {i+1} routes")

    except Exception as e:
        print(f"❌ Error on route {row['id']}: {e}")
        continue
# Out:
# ✅ Route 1 processed successfully
# ✅ Route 2 processed successfully
# ✅ Route 3 processed successfully
# ✅ Route 4 processed successfully
# ✅ Route 5 processed successfully
# ✅ Route 6 processed successfully
# ✅ Route 7 processed successfully
# ✅ Route 8 processed successfully
# ✅ Route 9 processed successfully
# ✅ Route 10 processed successfully
# 💾 Saved partial results after 10 routes
# ✅ Route 11 processed successfully
# ✅ Route 12 processed successfully
# ✅ Route 13 processed successfully
# ✅ Route 14 processed successfully
# ✅ Route 15 processed successfully
# ✅ Route 16 processed successfully
# ✅ Route 17 processed successfully
# ✅ Route 18 processed successfully
# ✅ Route 19 processed successfully
# ✅ Route 20 processed successfully
# 💾 Saved partial results after 20 routes
# ✅ Route 21 processed successfully
# ✅ Route 22 processed successfully
# ✅ Route 23 processed successfully
# ✅ Route 24 processed successfully
# ✅ Route 25 processed successfully
# ✅ Route 26 processed successfully
# ✅ Route 27 processed successfully
# ✅ Route 28 processed successfully
# ✅ Route 29 processed successfully
# ✅ Route 30 processed successfully
# 💾 Saved partial results after 30 routes
# ✅ Route 31 processed successfully
# ✅ Route 32 processed successfully
# ✅ Route 33 processed successfully
# ✅ Route 34 processed successfully
# ✅ Route 35 processed successfully
# ✅ Route 36 processed successfully
# ✅ Route 37 processed successfully
# ✅ Route 38 processed successfully
# ✅ Route 39 processed successfully
# ✅ Route 40 processed successfully
# 💾 Saved partial results after 40 routes
# ✅ Route 41 processed successfully
# ✅ Route 42 processed successfully
# ✅ Route 43 processed successfully
# ✅ Route 44 processed successfully
# ✅ Route 45 processed successfully
# ✅ Route 46 processed successfully
# ✅ Route 47 processed successfully
# ✅ Route 48 processed successfully
# ✅ Route 49 processed successfully
# ✅ Route 50 processed successfully
# 💾 Saved partial results after 50 routes
# ✅ Route 51 processed successfully
# ✅ Route 52 processed successfully
# ✅ Route 53 processed successfully
# ✅ Route 54 processed successfully
# ✅ Route 55 processed successfully
# ✅ Route 56 processed successfully
# ✅ Route 57 processed successfully
# ✅ Route 58 processed successfully
# ✅ Route 59 processed successfully
# ✅ Route 60 processed successfully
# 💾 Saved partial results after 60 routes
# ✅ Route 61 processed successfully
# ✅ Route 62 processed successfully
# ✅ Route 63 processed successfully
# ✅ Route 64 processed successfully
# ✅ Route 65 processed successfully
# ✅ Route 66 processed successfully
# ✅ Route 67 processed successfully
# ✅ Route 68 processed successfully
# ✅ Route 69 processed successfully
# ✅ Route 70 processed successfully
# 💾 Saved partial results after 70 routes
# ✅ Route 71 processed successfully
# ✅ Route 72 processed successfully
# ✅ Route 73 processed successfully
# ✅ Route 74 processed successfully
# ✅ Route 75 processed successfully
# ✅ Route 76 processed successfully
# ✅ Route 77 processed successfully
# ✅ Route 78 processed successfully
# ✅ Route 79 processed successfully
# ✅ Route 80 processed successfully
# 💾 Saved partial results after 80 routes
# ✅ Route 81 processed successfully
# ✅ Route 82 processed successfully
# ✅ Route 83 processed successfully
# ✅ Route 84 processed successfully
# ✅ Route 85 processed successfully
# ✅ Route 86 processed successfully
# ✅ Route 87 processed successfully
# ✅ Route 88 processed successfully
# ✅ Route 89 processed successfully
# ✅ Route 90 processed successfully
# 💾 Saved partial results after 90 routes
# ✅ Route 91 processed successfully
# ✅ Route 92 processed successfully
# ✅ Route 93 processed successfully
# ✅ Route 94 processed successfully
# ✅ Route 95 processed successfully
# ✅ Route 96 processed successfully
# ✅ Route 97 processed successfully
# ✅ Route 98 processed successfully
# ✅ Route 99 processed successfully
# ✅ Route 100 processed successfully
# 💾 Saved partial results after 100 routes
# ✅ Route 101 processed successfully
# ✅ Route 102 processed successfully
# ✅ Route 103 processed successfully
# ✅ Route 104 processed successfully
# ✅ Route 105 processed successfully
# ✅ Route 106 processed successfully
# ✅ Route 107 processed successfully
# ✅ Route 108 processed successfully
# ✅ Route 109 processed successfully
# ✅ Route 110 processed successfully
# 💾 Saved partial results after 110 routes
# ✅ Route 111 processed successfully
# ✅ Route 112 processed successfully
# ✅ Route 113 processed successfully
# ✅ Route 114 processed successfully
# ✅ Route 115 processed successfully
# ✅ Route 116 processed successfully
# ✅ Route 117 processed successfully
# ✅ Route 118 processed successfully
# ✅ Route 119 processed successfully
# ✅ Route 120 processed successfully
# 💾 Saved partial results after 120 routes
# ✅ Route 121 processed successfully
# ✅ Route 122 processed successfully
# ✅ Route 123 processed successfully
# ✅ Route 124 processed successfully
# ✅ Route 125 processed successfully
# ✅ Route 126 processed successfully
# ❌ Error on route 6459899:
# ✅ Route 128 processed successfully
# ✅ Route 129 processed successfully
# ✅ Route 130 processed successfully
# 💾 Saved partial results after 130 routes
# ✅ Route 131 processed successfully
# ✅ Route 132 processed successfully
# ✅ Route 133 processed successfully
# ✅ Route 134 processed successfully
# ✅ Route 135 processed successfully
# ✅ Route 136 processed successfully
# ✅ Route 137 processed successfully
# ✅ Route 138 processed successfully
# ✅ Route 139 processed successfully
# ✅ Route 140 processed successfully
# 💾 Saved partial results after 140 routes
# ✅ Route 141 processed successfully
# ✅ Route 142 processed successfully
# ✅ Route 143 processed successfully
# ✅ Route 144 processed successfully
# ✅ Route 145 processed successfully
# ✅ Route 146 processed successfully
# ✅ Route 147 processed successfully
# ✅ Route 148 processed successfully
# ✅ Route 149 processed successfully
# ✅ Route 150 processed successfully
# 💾 Saved partial results after 150 routes
# ✅ Route 151 processed successfully
# ✅ Route 152 processed successfully
# ✅ Route 153 processed successfully
# ✅ Route 154 processed successfully
# ✅ Route 155 processed successfully
# ✅ Route 156 processed successfully
# ✅ Route 157 processed successfully
# ✅ Route 158 processed successfully
# ✅ Route 159 processed successfully
# ✅ Route 160 processed successfully
# 💾 Saved partial results after 160 routes
# ✅ Route 161 processed successfully
# ✅ Route 162 processed successfully
# ✅ Route 163 processed successfully
# ✅ Route 164 processed successfully
# ✅ Route 165 processed successfully
# ✅ Route 166 processed successfully
# ✅ Route 167 processed successfully
# ✅ Route 168 processed successfully
# ✅ Route 169 processed successfully
# ✅ Route 170 processed successfully
# 💾 Saved partial results after 170 routes
# ✅ Route 171 processed successfully
# ✅ Route 172 processed successfully
# ✅ Route 173 processed successfully
# ✅ Route 174 processed successfully
# ✅ Route 175 processed successfully
# ✅ Route 176 processed successfully
# ✅ Route 177 processed successfully
# ✅ Route 178 processed successfully
# ✅ Route 179 processed successfully
# ✅ Route 180 processed successfully
# 💾 Saved partial results after 180 routes
# ✅ Route 181 processed successfully
# ✅ Route 182 processed successfully
# ✅ Route 183 processed successfully
# ✅ Route 184 processed successfully
# ✅ Route 185 processed successfully
# ✅ Route 186 processed successfully
# ✅ Route 187 processed successfully
# ✅ Route 188 processed successfully
# ✅ Route 189 processed successfully
# ✅ Route 190 processed successfully
# 💾 Saved partial results after 190 routes
# ✅ Route 191 processed successfully
# ✅ Route 192 processed successfully
# ✅ Route 193 processed successfully
# ✅ Route 194 processed successfully
# ✅ Route 195 processed successfully
# ✅ Route 196 processed successfully
# ✅ Route 197 processed successfully
# ✅ Route 198 processed successfully
# ✅ Route 199 processed successfully
# ✅ Route 200 processed successfully
# 💾 Saved partial results after 200 routes
# ✅ Route 201 processed successfully
# ✅ Route 202 processed successfully
# ✅ Route 203 processed successfully
# ✅ Route 204 processed successfully
# ✅ Route 205 processed successfully
# ✅ Route 206 processed successfully
# ✅ Route 207 processed successfully
# ✅ Route 208 processed successfully
# ✅ Route 209 processed successfully
# ✅ Route 210 processed successfully
# 💾 Saved partial results after 210 routes
# ✅ Route 211 processed successfully
# ✅ Route 212 processed successfully
# ✅ Route 213 processed successfully
# ✅ Route 214 processed successfully
# ✅ Route 215 processed successfully
# ✅ Route 216 processed successfully
# ✅ Route 217 processed successfully
# ✅ Route 218 processed successfully
# ✅ Route 219 processed successfully
# ✅ Route 220 processed successfully
# 💾 Saved partial results after 220 routes
# ✅ Route 221 processed successfully
# ✅ Route 222 processed successfully
# ✅ Route 223 processed successfully
# ✅ Route 224 processed successfully
# ✅ Route 225 processed successfully
# ✅ Route 226 processed successfully
# ✅ Route 227 processed successfully
# ✅ Route 228 processed successfully
# ✅ Route 229 processed successfully
# ✅ Route 230 processed successfully
# 💾 Saved partial results after 230 routes
# ✅ Route 231 processed successfully
# ✅ Route 232 processed successfully
# ✅ Route 233 processed successfully
# ✅ Route 234 processed successfully
# ✅ Route 235 processed successfully
# ✅ Route 236 processed successfully
# ✅ Route 237 processed successfully
# ✅ Route 238 processed successfully
# ✅ Route 239 processed successfully
# ✅ Route 240 processed successfully
# 💾 Saved partial results after 240 routes
# ✅ Route 241 processed successfully
# ✅ Route 242 processed successfully
# ✅ Route 243 processed successfully
# ✅ Route 244 processed successfully
# ✅ Route 245 processed successfully
# ✅ Route 246 processed successfully
# ✅ Route 247 processed successfully
# ✅ Route 248 processed successfully
# ✅ Route 249 processed successfully
# ✅ Route 250 processed successfully
# 💾 Saved partial results after 250 routes
# ✅ Route 251 processed successfully
# ✅ Route 252 processed successfully
# ✅ Route 253 processed successfully
# ✅ Route 254 processed successfully
# ✅ Route 255 processed successfully
# ✅ Route 256 processed successfully
# ✅ Route 257 processed successfully
# ✅ Route 258 processed successfully
# ✅ Route 259 processed successfully
# ✅ Route 260 processed successfully
# 💾 Saved partial results after 260 routes
# ✅ Route 261 processed successfully
# ✅ Route 262 processed successfully
# ✅ Route 263 processed successfully
# ✅ Route 264 processed successfully
# ✅ Route 265 processed successfully
# ✅ Route 266 processed successfully
# ✅ Route 267 processed successfully
# ✅ Route 268 processed successfully
# ✅ Route 269 processed successfully
# ✅ Route 270 processed successfully
# 💾 Saved partial results after 270 routes
# ✅ Route 271 processed successfully
# ✅ Route 272 processed successfully
# ✅ Route 273 processed successfully
# ✅ Route 274 processed successfully
# ✅ Route 275 processed successfully
# ✅ Route 276 processed successfully
# ✅ Route 277 processed successfully
# ✅ Route 278 processed successfully
# ✅ Route 279 processed successfully
# ✅ Route 280 processed successfully
# 💾 Saved partial results after 280 routes
# ✅ Route 281 processed successfully
# ✅ Route 282 processed successfully
# ✅ Route 283 processed successfully
# ✅ Route 284 processed successfully
# ✅ Route 285 processed successfully
# ✅ Route 286 processed successfully
# ✅ Route 287 processed successfully
# ✅ Route 288 processed successfully
# ✅ Route 289 processed successfully
# ✅ Route 290 processed successfully
# 💾 Saved partial results after 290 routes
# ✅ Route 291 processed successfully
# ✅ Route 292 processed successfully
# ✅ Route 293 processed successfully
# ✅ Route 294 processed successfully
# ✅ Route 295 processed successfully
# ✅ Route 296 processed successfully
# ✅ Route 297 processed successfully
# ✅ Route 298 processed successfully
# ✅ Route 299 processed successfully
# ✅ Route 300 processed successfully
# 💾 Saved partial results after 300 routes
# ✅ Route 301 processed successfully
# ✅ Route 302 processed successfully
# ✅ Route 303 processed successfully
# ✅ Route 304 processed successfully
# ✅ Route 305 processed successfully
# ✅ Route 306 processed successfully
# ✅ Route 307 processed successfully
# ✅ Route 308 processed successfully
# ✅ Route 309 processed successfully
# ✅ Route 310 processed successfully
# 💾 Saved partial results after 310 routes
# ✅ Route 311 processed successfully
# ✅ Route 312 processed successfully
# ✅ Route 313 processed successfully
# ✅ Route 314 processed successfully
# ✅ Route 315 processed successfully
# ✅ Route 316 processed successfully
# ✅ Route 317 processed successfully
# ✅ Route 318 processed successfully
# ✅ Route 319 processed successfully
# ✅ Route 320 processed successfully
# 💾 Saved partial results after 320 routes
# ✅ Route 321 processed successfully
# ✅ Route 322 processed successfully
# ✅ Route 323 processed successfully
# ✅ Route 324 processed successfully
# ✅ Route 325 processed successfully
# ✅ Route 326 processed successfully
# ✅ Route 327 processed successfully
# ✅ Route 328 processed successfully
# ✅ Route 329 processed successfully
# ✅ Route 330 processed successfully
# 💾 Saved partial results after 330 routes
# ✅ Route 331 processed successfully
# ✅ Route 332 processed successfully
# ✅ Route 333 processed successfully
# ✅ Route 334 processed successfully
# ✅ Route 335 processed successfully
# ✅ Route 336 processed successfully
# ✅ Route 337 processed successfully
# ✅ Route 338 processed successfully
# ✅ Route 339 processed successfully
# ✅ Route 340 processed successfully
# 💾 Saved partial results after 340 routes
# ✅ Route 341 processed successfully
# ✅ Route 342 processed successfully
# ✅ Route 343 processed successfully
# ✅ Route 344 processed successfully
# ✅ Route 345 processed successfully
# ✅ Route 346 processed successfully
# ✅ Route 347 processed successfully
# ✅ Route 348 processed successfully
# ✅ Route 349 processed successfully
# ✅ Route 350 processed successfully
# 💾 Saved partial results after 350 routes
# ✅ Route 351 processed successfully
# ✅ Route 352 processed successfully
# ✅ Route 353 processed successfully
# ✅ Route 354 processed successfully
# ✅ Route 355 processed successfully
# ✅ Route 356 processed successfully
# ✅ Route 357 processed successfully
# ✅ Route 358 processed successfully
# ✅ Route 359 processed successfully
# ✅ Route 360 processed successfully
# 💾 Saved partial results after 360 routes
# ❌ Error on route 13887800: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ✅ Route 362 processed successfully
# ✅ Route 363 processed successfully
# ✅ Route 364 processed successfully
# ✅ Route 365 processed successfully
# ✅ Route 366 processed successfully
# ✅ Route 367 processed successfully
# ✅ Route 368 processed successfully
# ✅ Route 369 processed successfully
# ✅ Route 370 processed successfully
# 💾 Saved partial results after 370 routes
# ✅ Route 371 processed successfully
# ✅ Route 372 processed successfully
# ✅ Route 373 processed successfully
# ✅ Route 374 processed successfully
# ✅ Route 375 processed successfully
# ✅ Route 376 processed successfully
# ✅ Route 377 processed successfully
# ✅ Route 378 processed successfully
# ✅ Route 379 processed successfully
# ✅ Route 380 processed successfully
# 💾 Saved partial results after 380 routes
# ✅ Route 381 processed successfully
# ✅ Route 382 processed successfully
# ✅ Route 383 processed successfully
# ✅ Route 384 processed successfully
# ✅ Route 385 processed successfully
# ✅ Route 386 processed successfully
# ✅ Route 387 processed successfully
# ✅ Route 388 processed successfully
# ✅ Route 389 processed successfully
# ✅ Route 390 processed successfully
# 💾 Saved partial results after 390 routes
# ✅ Route 391 processed successfully
# ✅ Route 392 processed successfully
# ✅ Route 393 processed successfully
# ✅ Route 394 processed successfully
# ✅ Route 395 processed successfully
# ✅ Route 396 processed successfully
# ✅ Route 397 processed successfully
# ✅ Route 398 processed successfully
# ✅ Route 399 processed successfully
# ✅ Route 400 processed successfully
# 💾 Saved partial results after 400 routes
# ✅ Route 401 processed successfully
# ✅ Route 402 processed successfully
# ✅ Route 403 processed successfully
# ✅ Route 404 processed successfully
# ✅ Route 405 processed successfully
# ✅ Route 406 processed successfully
# ✅ Route 407 processed successfully
# ✅ Route 408 processed successfully
# ✅ Route 409 processed successfully
# ✅ Route 410 processed successfully
# 💾 Saved partial results after 410 routes
# ✅ Route 411 processed successfully
# ✅ Route 412 processed successfully
# ✅ Route 413 processed successfully
# ✅ Route 414 processed successfully
# ✅ Route 415 processed successfully
# ✅ Route 416 processed successfully
# ✅ Route 417 processed successfully
# ✅ Route 418 processed successfully
# ✅ Route 419 processed successfully
# ✅ Route 420 processed successfully
# 💾 Saved partial results after 420 routes
# ✅ Route 421 processed successfully
# ✅ Route 422 processed successfully
# ✅ Route 423 processed successfully
# ✅ Route 424 processed successfully
# ✅ Route 425 processed successfully
# ✅ Route 426 processed successfully
# ✅ Route 427 processed successfully
# ✅ Route 428 processed successfully
# ✅ Route 429 processed successfully
# ✅ Route 430 processed successfully
# 💾 Saved partial results after 430 routes
# ✅ Route 431 processed successfully
# ✅ Route 432 processed successfully
# ✅ Route 433 processed successfully
# ✅ Route 434 processed successfully
# ✅ Route 435 processed successfully
# ✅ Route 436 processed successfully
# ✅ Route 437 processed successfully
# ✅ Route 438 processed successfully
# ✅ Route 439 processed successfully
# ✅ Route 440 processed successfully
# 💾 Saved partial results after 440 routes
# ✅ Route 441 processed successfully
# ✅ Route 442 processed successfully
# ✅ Route 443 processed successfully
# ✅ Route 444 processed successfully
# ✅ Route 445 processed successfully
# ✅ Route 446 processed successfully
# ✅ Route 447 processed successfully
# ✅ Route 448 processed successfully
# ✅ Route 449 processed successfully
# ✅ Route 450 processed successfully
# 💾 Saved partial results after 450 routes
# ✅ Route 451 processed successfully
# ✅ Route 452 processed successfully
# ✅ Route 453 processed successfully
# ✅ Route 454 processed successfully
# ✅ Route 455 processed successfully
# ✅ Route 456 processed successfully
# ✅ Route 457 processed successfully
# ✅ Route 458 processed successfully
# ✅ Route 459 processed successfully
# ✅ Route 460 processed successfully
# 💾 Saved partial results after 460 routes
# ✅ Route 461 processed successfully
# ✅ Route 462 processed successfully
# ✅ Route 463 processed successfully
# ✅ Route 464 processed successfully
# ✅ Route 465 processed successfully
# ✅ Route 466 processed successfully
# ✅ Route 467 processed successfully
# ✅ Route 468 processed successfully
# ✅ Route 469 processed successfully
# ✅ Route 470 processed successfully
# 💾 Saved partial results after 470 routes
# ✅ Route 471 processed successfully
# ✅ Route 472 processed successfully
# ✅ Route 473 processed successfully
# ✅ Route 474 processed successfully
# ✅ Route 475 processed successfully
# ✅ Route 476 processed successfully
# ✅ Route 477 processed successfully
# ✅ Route 478 processed successfully
# ✅ Route 479 processed successfully
# ✅ Route 480 processed successfully
# 💾 Saved partial results after 480 routes
# ✅ Route 481 processed successfully
# ✅ Route 482 processed successfully
# ✅ Route 483 processed successfully
# ✅ Route 484 processed successfully
# ✅ Route 485 processed successfully
# ✅ Route 486 processed successfully
# ✅ Route 487 processed successfully
# ✅ Route 488 processed successfully
# ✅ Route 489 processed successfully
# ✅ Route 490 processed successfully
# 💾 Saved partial results after 490 routes
# ✅ Route 491 processed successfully
# ✅ Route 492 processed successfully
# ✅ Route 493 processed successfully
# ✅ Route 494 processed successfully
# ✅ Route 495 processed successfully
# ✅ Route 496 processed successfully
# ✅ Route 497 processed successfully
# ✅ Route 498 processed successfully
# ✅ Route 499 processed successfully
# ✅ Route 500 processed successfully
# 💾 Saved partial results after 500 routes
# ✅ Route 501 processed successfully
# ✅ Route 502 processed successfully
# ✅ Route 503 processed successfully
# ✅ Route 504 processed successfully
# ✅ Route 505 processed successfully
# ✅ Route 506 processed successfully
# ✅ Route 507 processed successfully
# ✅ Route 508 processed successfully
# ✅ Route 509 processed successfully
# ✅ Route 510 processed successfully
# 💾 Saved partial results after 510 routes
# ✅ Route 511 processed successfully
# ✅ Route 512 processed successfully
# ✅ Route 513 processed successfully
# ✅ Route 514 processed successfully
# ✅ Route 515 processed successfully
# ✅ Route 516 processed successfully
# ✅ Route 517 processed successfully
# ✅ Route 518 processed successfully
# ✅ Route 519 processed successfully
# ✅ Route 520 processed successfully
# 💾 Saved partial results after 520 routes
# ✅ Route 521 processed successfully
# ✅ Route 522 processed successfully
# ✅ Route 523 processed successfully
# ✅ Route 524 processed successfully
# ✅ Route 525 processed successfully

# %%
#-----------------------------------------------CHANGE FILE NAME HERE--------------------------------------#
final_path = "ors_route_results_Provence.json"
#-----------------------------------------------CHANGE FILE NAME HERE--------------------------------------#

# %%
final_path
# Out:
# 'ors_route_results_Provence.json'

# %%
with open(final_path, "w") as f:
    json.dump(results, f, indent=2)

# %%
print(f"\n🎉 Finished run — processed {len(results)} routes.")
print(f"📁 Full output saved to {final_path}")
# Out:
# 🎉 Finished run — processed 523 routes.
# 📁 Full output saved to ors_route_results_Provence.json

# %%
#-----------------------------------------------CHANGE FILE NAME HERE--------------------------------------#
with open("ors_route_results_Provence.json", "r") as f:
    results = json.load(f)
#-----------------------------------------------CHANGE FILE NAME HERE--------------------------------------#

# %%
# Convert to a DataFrame
df = pd.DataFrame(results)

# %%
# Display the first few rows
display(df.head(1))
# Out:
#        id                    name  distance_m  duration_s ascent_m descent_m  \
# 0  168466  Boucles du 13 Camargue     15578.0      3116.4   [30.3]    [30.3]
#
#    steps  turns                                      surface        waytype  \
# 0      6      2  [[0, 129, 3], [129, 131, 0], [131, 185, 3]]  [[0, 185, 2]]
#
#      waycategory      steepness
# 0  [[0, 185, 0]]  [[0, 185, 0]]

# %%
#-----------------------------------------------CHANGE FILE NAME HERE--------------------------------------#
df.to_csv("Provence.csv", index=False)
#-----------------------------------------------CHANGE FILE NAME HERE--------------------------------------#

# %%
df
# Out:
#            id                                     name  distance_m  \
# 0      168466                   Boucles du 13 Camargue     15578.0
# 1      168472      Boucles du 13 - La Chaîne des Côtes       388.2
# 2      168474           Boucles du 13 - Saintes Maries         NaN
# 3      168475  Les boucles du 13 - Autour de Silvacane      4528.4
# 4      168476            D’Arles à l’étang du Vaccarès        45.9
# ..        ...                                      ...         ...
# 518  19816737           Vallées, châtaignes et volcans      6426.4
# 519  19824619          Uzès à Saint-Quentin-la-Poterie      3509.2
# 520  19849376                                      V65         NaN
# 521  19849377                                      V65      1213.6
# 522  19849545                                      V65       417.6
#
#      duration_s ascent_m descent_m  steps  turns  \
# 0        3116.4   [30.3]    [30.3]      6      2
# 1          77.6    [0.0]    [11.0]      6      4
# 2           NaN    [0.0]     [0.0]      1      0
# 3         905.7   [23.2]    [12.2]      2      0
# 4           9.2    [1.0]     [0.0]      2      0
# ..          ...      ...       ...    ...    ...
# 518      1285.3  [387.3]   [180.3]      3      0
# 519       720.4    [9.0]    [43.0]     10      7
# 520         NaN    [0.0]     [0.0]      1      0
# 521       285.3   [27.0]    [24.0]     10      6
# 522        83.5   [12.0]     [9.0]      2      0
#
#                                                surface  \
# 0          [[0, 129, 3], [129, 131, 0], [131, 185, 3]]
# 1    [[0, 9, 3], [9, 17, 0], [17, 25, 3], [25, 28, ...
# 2                                                   []
# 3                                         [[0, 56, 3]]
# 4                                          [[0, 3, 3]]
# ..                                                 ...
# 518                           [[0, 1, 0], [1, 270, 3]]
# 519  [[0, 35, 3], [35, 36, 7], [36, 57, 3], [57, 66...
# 520                                                 []
# 521               [[0, 4, 3], [4, 43, 0], [43, 62, 3]]
# 522                                       [[0, 12, 3]]
#
#                                                waytype    waycategory  \
# 0                                        [[0, 185, 2]]  [[0, 185, 0]]
# 1                                         [[0, 29, 2]]   [[0, 29, 0]]
# 2                                                   []             []
# 3                                         [[0, 56, 2]]   [[0, 56, 0]]
# 4                                          [[0, 3, 2]]    [[0, 3, 0]]
# ..                                                 ...            ...
# 518                           [[0, 3, 3], [3, 270, 2]]  [[0, 270, 0]]
# 519  [[0, 15, 4], [15, 33, 3], [33, 35, 5], [35, 57...   [[0, 81, 0]]
# 520                                                 []             []
# 521  [[0, 4, 2], [4, 7, 4], [7, 14, 5], [14, 22, 3]...   [[0, 62, 0]]
# 522                                       [[0, 12, 6]]   [[0, 12, 0]]
#
#                                              steepness
# 0                                        [[0, 185, 0]]
# 1                                        [[0, 29, -1]]
# 2                                                   []
# 3                                         [[0, 56, 0]]
# 4                                          [[0, 3, 0]]
# ..                                                 ...
# 518  [[0, 12, 3], [12, 27, -1], [27, 28, -5], [28, ...
# 519                         [[0, 21, -1], [21, 81, 0]]
# 520                                                 []
# 521                                       [[0, 62, 1]]
# 522                                       [[0, 12, 1]]
#
# [523 rows x 12 columns]

# %%
from google.cloud import storage
import os

def upload_json_folder_to_gcs(local_folder: str, bucket_name: str, destination_folder: str):
    """
    Uploads all JSON files from a local folder to a folder in a Google Cloud Storage bucket.

    Args:
        local_folder (str): Path to the local folder containing JSON files.
        bucket_name (str): Name of the Google Cloud Storage bucket.
        destination_folder (str): Folder path inside the bucket (prefix).
                                  Example: "data/json-files"

    Returns:
        None
    """
    # Initialize client
    client = storage.Client(project="cyclemore")
    bucket = client.bucket(bucket_name)

    # Ensure folder path ends correctly
    destination_folder = destination_folder.strip("/")

    # Loop over all files
    for filename in os.listdir(local_folder):
        if filename.endswith(".json"):
            local_path = os.path.join(local_folder, filename)
            blob_path = f"{destination_folder}/{filename}"  # Path in bucket

            blob = bucket.blob(blob_path)
            blob.upload_from_filename(local_path)

            print(f"Uploaded: {local_path} → gs://{bucket_name}/{blob_path}")

# %%
upload_json_folder_to_gcs(
    local_folder="/Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence",
    bucket_name="cycle_more_bucket",
    destination_folder="raw_ors_data/provence"
)
# Out:
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9730960.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9730960.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10579284.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10579284.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_17751305.json → gs://cycle_more_bucket/raw_ors_data/provence/route_17751305.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10168097.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10168097.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13885176.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13885176.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_196615.json → gs://cycle_more_bucket/raw_ors_data/provence/route_196615.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_16734187.json → gs://cycle_more_bucket/raw_ors_data/provence/route_16734187.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_5139968.json → gs://cycle_more_bucket/raw_ors_data/provence/route_5139968.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10339897.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10339897.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_3634083.json → gs://cycle_more_bucket/raw_ors_data/provence/route_3634083.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_11526443.json → gs://cycle_more_bucket/raw_ors_data/provence/route_11526443.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_2313196.json → gs://cycle_more_bucket/raw_ors_data/provence/route_2313196.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_11271874.json → gs://cycle_more_bucket/raw_ors_data/provence/route_11271874.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_17055357.json → gs://cycle_more_bucket/raw_ors_data/provence/route_17055357.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_11182223.json → gs://cycle_more_bucket/raw_ors_data/provence/route_11182223.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_2807947.json → gs://cycle_more_bucket/raw_ors_data/provence/route_2807947.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_4867427.json → gs://cycle_more_bucket/raw_ors_data/provence/route_4867427.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10013140.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10013140.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13849735.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13849735.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10124413.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10124413.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_2674708.json → gs://cycle_more_bucket/raw_ors_data/provence/route_2674708.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_2311304.json → gs://cycle_more_bucket/raw_ors_data/provence/route_2311304.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13924999.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13924999.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9636083.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9636083.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9986588.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9986588.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13432338.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13432338.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_4867466.json → gs://cycle_more_bucket/raw_ors_data/provence/route_4867466.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_14752176.json → gs://cycle_more_bucket/raw_ors_data/provence/route_14752176.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_14466493.json → gs://cycle_more_bucket/raw_ors_data/provence/route_14466493.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_5159200.json → gs://cycle_more_bucket/raw_ors_data/provence/route_5159200.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_17499053.json → gs://cycle_more_bucket/raw_ors_data/provence/route_17499053.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10170433.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10170433.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_14216270.json → gs://cycle_more_bucket/raw_ors_data/provence/route_14216270.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10180237.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10180237.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9352375.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9352375.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10305673.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10305673.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13336130.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13336130.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10116807.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10116807.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_18070183.json → gs://cycle_more_bucket/raw_ors_data/provence/route_18070183.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_17141892.json → gs://cycle_more_bucket/raw_ors_data/provence/route_17141892.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13899948.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13899948.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_6690014.json → gs://cycle_more_bucket/raw_ors_data/provence/route_6690014.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9636324.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9636324.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_3273110.json → gs://cycle_more_bucket/raw_ors_data/provence/route_3273110.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_12873590.json → gs://cycle_more_bucket/raw_ors_data/provence/route_12873590.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9733751.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9733751.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10398013.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10398013.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_2575584.json → gs://cycle_more_bucket/raw_ors_data/provence/route_2575584.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9758823.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9758823.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_8611793.json → gs://cycle_more_bucket/raw_ors_data/provence/route_8611793.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_19632028.json → gs://cycle_more_bucket/raw_ors_data/provence/route_19632028.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_16748984.json → gs://cycle_more_bucket/raw_ors_data/provence/route_16748984.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10794824.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10794824.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10422116.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10422116.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_7243598.json → gs://cycle_more_bucket/raw_ors_data/provence/route_7243598.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_6881723.json → gs://cycle_more_bucket/raw_ors_data/provence/route_6881723.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_16003154.json → gs://cycle_more_bucket/raw_ors_data/provence/route_16003154.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_7567812.json → gs://cycle_more_bucket/raw_ors_data/provence/route_7567812.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13925900.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13925900.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_18020031.json → gs://cycle_more_bucket/raw_ors_data/provence/route_18020031.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_17059641.json → gs://cycle_more_bucket/raw_ors_data/provence/route_17059641.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9583387.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9583387.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_16179094.json → gs://cycle_more_bucket/raw_ors_data/provence/route_16179094.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_2808169.json → gs://cycle_more_bucket/raw_ors_data/provence/route_2808169.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_16794144.json → gs://cycle_more_bucket/raw_ors_data/provence/route_16794144.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_5134004.json → gs://cycle_more_bucket/raw_ors_data/provence/route_5134004.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_14183350.json → gs://cycle_more_bucket/raw_ors_data/provence/route_14183350.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_2744750.json → gs://cycle_more_bucket/raw_ors_data/provence/route_2744750.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_5286349.json → gs://cycle_more_bucket/raw_ors_data/provence/route_5286349.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_17459310.json → gs://cycle_more_bucket/raw_ors_data/provence/route_17459310.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10808304.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10808304.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13881791.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13881791.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10243865.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10243865.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10408894.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10408894.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10409769.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10409769.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13154840.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13154840.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_8310267.json → gs://cycle_more_bucket/raw_ors_data/provence/route_8310267.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13433066.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13433066.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13925014.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13925014.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_16233441.json → gs://cycle_more_bucket/raw_ors_data/provence/route_16233441.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_16078118.json → gs://cycle_more_bucket/raw_ors_data/provence/route_16078118.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9994296.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9994296.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13956428.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13956428.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_2744751.json → gs://cycle_more_bucket/raw_ors_data/provence/route_2744751.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10398090.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10398090.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_2813698.json → gs://cycle_more_bucket/raw_ors_data/provence/route_2813698.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9742054.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9742054.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_16708026.json → gs://cycle_more_bucket/raw_ors_data/provence/route_16708026.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_12774397.json → gs://cycle_more_bucket/raw_ors_data/provence/route_12774397.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10409800.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10409800.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_8611585.json → gs://cycle_more_bucket/raw_ors_data/provence/route_8611585.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_19849545.json → gs://cycle_more_bucket/raw_ors_data/provence/route_19849545.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13887605.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13887605.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_16794145.json → gs://cycle_more_bucket/raw_ors_data/provence/route_16794145.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13928958.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13928958.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13952304.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13952304.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_17141954.json → gs://cycle_more_bucket/raw_ors_data/provence/route_17141954.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10408929.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10408929.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_18652343.json → gs://cycle_more_bucket/raw_ors_data/provence/route_18652343.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13899565.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13899565.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_8448409.json → gs://cycle_more_bucket/raw_ors_data/provence/route_8448409.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_6209920.json → gs://cycle_more_bucket/raw_ors_data/provence/route_6209920.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9745197.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9745197.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13852699.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13852699.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_18208895.json → gs://cycle_more_bucket/raw_ors_data/provence/route_18208895.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_543195.json → gs://cycle_more_bucket/raw_ors_data/provence/route_543195.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_19119112.json → gs://cycle_more_bucket/raw_ors_data/provence/route_19119112.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_4037348.json → gs://cycle_more_bucket/raw_ors_data/provence/route_4037348.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_14782598.json → gs://cycle_more_bucket/raw_ors_data/provence/route_14782598.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_17426734.json → gs://cycle_more_bucket/raw_ors_data/provence/route_17426734.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_16794094.json → gs://cycle_more_bucket/raw_ors_data/provence/route_16794094.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_7627798.json → gs://cycle_more_bucket/raw_ors_data/provence/route_7627798.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_11560384.json → gs://cycle_more_bucket/raw_ors_data/provence/route_11560384.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_11246462.json → gs://cycle_more_bucket/raw_ors_data/provence/route_11246462.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9330092.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9330092.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_15975844.json → gs://cycle_more_bucket/raw_ors_data/provence/route_15975844.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10339875.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10339875.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_2575593.json → gs://cycle_more_bucket/raw_ors_data/provence/route_2575593.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_17875242.json → gs://cycle_more_bucket/raw_ors_data/provence/route_17875242.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10423593.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10423593.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_6690015.json → gs://cycle_more_bucket/raw_ors_data/provence/route_6690015.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_17499025.json → gs://cycle_more_bucket/raw_ors_data/provence/route_17499025.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_14183691.json → gs://cycle_more_bucket/raw_ors_data/provence/route_14183691.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10408944.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10408944.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_7564614.json → gs://cycle_more_bucket/raw_ors_data/provence/route_7564614.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_17689559.json → gs://cycle_more_bucket/raw_ors_data/provence/route_17689559.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_5244036.json → gs://cycle_more_bucket/raw_ors_data/provence/route_5244036.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10408933.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10408933.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_15583536.json → gs://cycle_more_bucket/raw_ors_data/provence/route_15583536.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_19807563.json → gs://cycle_more_bucket/raw_ors_data/provence/route_19807563.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9735889.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9735889.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_168472.json → gs://cycle_more_bucket/raw_ors_data/provence/route_168472.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13928942.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13928942.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10013116.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10013116.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_17847094.json → gs://cycle_more_bucket/raw_ors_data/provence/route_17847094.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_18628769.json → gs://cycle_more_bucket/raw_ors_data/provence/route_18628769.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_16730517.json → gs://cycle_more_bucket/raw_ors_data/provence/route_16730517.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_8096244.json → gs://cycle_more_bucket/raw_ors_data/provence/route_8096244.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_5233058.json → gs://cycle_more_bucket/raw_ors_data/provence/route_5233058.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_17055356.json → gs://cycle_more_bucket/raw_ors_data/provence/route_17055356.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10442188.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10442188.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9997064.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9997064.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10116959.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10116959.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_12364259.json → gs://cycle_more_bucket/raw_ors_data/provence/route_12364259.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10192374.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10192374.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13433115.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13433115.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9759141.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9759141.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_6621429.json → gs://cycle_more_bucket/raw_ors_data/provence/route_6621429.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_14349467.json → gs://cycle_more_bucket/raw_ors_data/provence/route_14349467.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9921508.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9921508.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_19286571.json → gs://cycle_more_bucket/raw_ors_data/provence/route_19286571.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_14197790.json → gs://cycle_more_bucket/raw_ors_data/provence/route_14197790.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_4867440.json → gs://cycle_more_bucket/raw_ors_data/provence/route_4867440.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10014318.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10014318.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_6228981.json → gs://cycle_more_bucket/raw_ors_data/provence/route_6228981.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9352353.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9352353.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9314026.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9314026.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_1801183.json → gs://cycle_more_bucket/raw_ors_data/provence/route_1801183.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_2739358.json → gs://cycle_more_bucket/raw_ors_data/provence/route_2739358.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_15975906.json → gs://cycle_more_bucket/raw_ors_data/provence/route_15975906.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_286534.json → gs://cycle_more_bucket/raw_ors_data/provence/route_286534.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_16794139.json → gs://cycle_more_bucket/raw_ors_data/provence/route_16794139.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13041623.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13041623.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9938154.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9938154.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10390921.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10390921.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_16061216.json → gs://cycle_more_bucket/raw_ors_data/provence/route_16061216.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_537729.json → gs://cycle_more_bucket/raw_ors_data/provence/route_537729.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_12173589.json → gs://cycle_more_bucket/raw_ors_data/provence/route_12173589.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_11129243.json → gs://cycle_more_bucket/raw_ors_data/provence/route_11129243.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10794526.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10794526.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9759019.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9759019.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_3839123.json → gs://cycle_more_bucket/raw_ors_data/provence/route_3839123.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_11009578.json → gs://cycle_more_bucket/raw_ors_data/provence/route_11009578.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_19824619.json → gs://cycle_more_bucket/raw_ors_data/provence/route_19824619.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_14207538.json → gs://cycle_more_bucket/raw_ors_data/provence/route_14207538.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9756544.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9756544.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_11733679.json → gs://cycle_more_bucket/raw_ors_data/provence/route_11733679.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_15998232.json → gs://cycle_more_bucket/raw_ors_data/provence/route_15998232.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_1695108.json → gs://cycle_more_bucket/raw_ors_data/provence/route_1695108.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_7346128.json → gs://cycle_more_bucket/raw_ors_data/provence/route_7346128.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_8907278.json → gs://cycle_more_bucket/raw_ors_data/provence/route_8907278.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13432774.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13432774.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9986982.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9986982.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_19785692.json → gs://cycle_more_bucket/raw_ors_data/provence/route_19785692.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_14222267.json → gs://cycle_more_bucket/raw_ors_data/provence/route_14222267.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_14562612.json → gs://cycle_more_bucket/raw_ors_data/provence/route_14562612.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_12252346.json → gs://cycle_more_bucket/raw_ors_data/provence/route_12252346.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13008363.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13008363.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10408938.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10408938.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_2744633.json → gs://cycle_more_bucket/raw_ors_data/provence/route_2744633.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13841102.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13841102.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9907089.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9907089.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_12774471.json → gs://cycle_more_bucket/raw_ors_data/provence/route_12774471.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_11640003.json → gs://cycle_more_bucket/raw_ors_data/provence/route_11640003.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_2310591.json → gs://cycle_more_bucket/raw_ors_data/provence/route_2310591.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10421819.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10421819.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_2575577.json → gs://cycle_more_bucket/raw_ors_data/provence/route_2575577.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_11571658.json → gs://cycle_more_bucket/raw_ors_data/provence/route_11571658.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10409759.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10409759.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10398330.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10398330.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_17055306.json → gs://cycle_more_bucket/raw_ors_data/provence/route_17055306.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_6090947.json → gs://cycle_more_bucket/raw_ors_data/provence/route_6090947.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9758983.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9758983.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_6190633.json → gs://cycle_more_bucket/raw_ors_data/provence/route_6190633.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_5178189.json → gs://cycle_more_bucket/raw_ors_data/provence/route_5178189.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_17060273.json → gs://cycle_more_bucket/raw_ors_data/provence/route_17060273.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_15711700.json → gs://cycle_more_bucket/raw_ors_data/provence/route_15711700.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10408959.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10408959.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_17840644.json → gs://cycle_more_bucket/raw_ors_data/provence/route_17840644.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_11132497.json → gs://cycle_more_bucket/raw_ors_data/provence/route_11132497.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_3811994.json → gs://cycle_more_bucket/raw_ors_data/provence/route_3811994.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_11182198.json → gs://cycle_more_bucket/raw_ors_data/provence/route_11182198.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_16741845.json → gs://cycle_more_bucket/raw_ors_data/provence/route_16741845.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13433186.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13433186.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_3840020.json → gs://cycle_more_bucket/raw_ors_data/provence/route_3840020.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_19587214.json → gs://cycle_more_bucket/raw_ors_data/provence/route_19587214.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_16733691.json → gs://cycle_more_bucket/raw_ors_data/provence/route_16733691.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_6197162.json → gs://cycle_more_bucket/raw_ors_data/provence/route_6197162.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_17499002.json → gs://cycle_more_bucket/raw_ors_data/provence/route_17499002.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_2808175.json → gs://cycle_more_bucket/raw_ors_data/provence/route_2808175.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_168475.json → gs://cycle_more_bucket/raw_ors_data/provence/route_168475.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9177023.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9177023.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_1782624.json → gs://cycle_more_bucket/raw_ors_data/provence/route_1782624.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13894825.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13894825.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_6194133.json → gs://cycle_more_bucket/raw_ors_data/provence/route_6194133.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_6613318.json → gs://cycle_more_bucket/raw_ors_data/provence/route_6613318.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9758957.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9758957.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_19587038.json → gs://cycle_more_bucket/raw_ors_data/provence/route_19587038.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_539868.json → gs://cycle_more_bucket/raw_ors_data/provence/route_539868.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9177022.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9177022.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_11612748.json → gs://cycle_more_bucket/raw_ors_data/provence/route_11612748.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_2813738.json → gs://cycle_more_bucket/raw_ors_data/provence/route_2813738.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_18244774.json → gs://cycle_more_bucket/raw_ors_data/provence/route_18244774.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_17689508.json → gs://cycle_more_bucket/raw_ors_data/provence/route_17689508.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_168474.json → gs://cycle_more_bucket/raw_ors_data/provence/route_168474.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_19286946.json → gs://cycle_more_bucket/raw_ors_data/provence/route_19286946.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_17141677.json → gs://cycle_more_bucket/raw_ors_data/provence/route_17141677.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_17141909.json → gs://cycle_more_bucket/raw_ors_data/provence/route_17141909.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_2132646.json → gs://cycle_more_bucket/raw_ors_data/provence/route_2132646.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_8448395.json → gs://cycle_more_bucket/raw_ors_data/provence/route_8448395.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9759080.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9759080.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_17689477.json → gs://cycle_more_bucket/raw_ors_data/provence/route_17689477.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_5178188.json → gs://cycle_more_bucket/raw_ors_data/provence/route_5178188.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_3490997.json → gs://cycle_more_bucket/raw_ors_data/provence/route_3490997.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_17055307.json → gs://cycle_more_bucket/raw_ors_data/provence/route_17055307.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_3534897.json → gs://cycle_more_bucket/raw_ors_data/provence/route_3534897.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_6132245.json → gs://cycle_more_bucket/raw_ors_data/provence/route_6132245.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_15568811.json → gs://cycle_more_bucket/raw_ors_data/provence/route_15568811.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_14748012.json → gs://cycle_more_bucket/raw_ors_data/provence/route_14748012.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13929338.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13929338.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_3151746.json → gs://cycle_more_bucket/raw_ors_data/provence/route_3151746.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_14222138.json → gs://cycle_more_bucket/raw_ors_data/provence/route_14222138.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_7642515.json → gs://cycle_more_bucket/raw_ors_data/provence/route_7642515.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10398242.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10398242.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_12252347.json → gs://cycle_more_bucket/raw_ors_data/provence/route_12252347.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_6229201.json → gs://cycle_more_bucket/raw_ors_data/provence/route_6229201.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10210554.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10210554.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10808303.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10808303.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_15992852.json → gs://cycle_more_bucket/raw_ors_data/provence/route_15992852.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_18179815.json → gs://cycle_more_bucket/raw_ors_data/provence/route_18179815.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_3942372.json → gs://cycle_more_bucket/raw_ors_data/provence/route_3942372.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10421896.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10421896.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10409810.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10409810.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10797370.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10797370.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_7564940.json → gs://cycle_more_bucket/raw_ors_data/provence/route_7564940.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_19586326.json → gs://cycle_more_bucket/raw_ors_data/provence/route_19586326.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10397973.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10397973.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13956414.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13956414.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_5341998.json → gs://cycle_more_bucket/raw_ors_data/provence/route_5341998.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_6459899.json → gs://cycle_more_bucket/raw_ors_data/provence/route_6459899.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_1435822.json → gs://cycle_more_bucket/raw_ors_data/provence/route_1435822.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_4625554.json → gs://cycle_more_bucket/raw_ors_data/provence/route_4625554.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10421910.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10421910.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_2131158.json → gs://cycle_more_bucket/raw_ors_data/provence/route_2131158.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10808913.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10808913.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9924526.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9924526.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_5167676.json → gs://cycle_more_bucket/raw_ors_data/provence/route_5167676.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_17141753.json → gs://cycle_more_bucket/raw_ors_data/provence/route_17141753.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_19340470.json → gs://cycle_more_bucket/raw_ors_data/provence/route_19340470.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_16794138.json → gs://cycle_more_bucket/raw_ors_data/provence/route_16794138.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_16708108.json → gs://cycle_more_bucket/raw_ors_data/provence/route_16708108.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_17800082.json → gs://cycle_more_bucket/raw_ors_data/provence/route_17800082.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10398002.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10398002.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_12717294.json → gs://cycle_more_bucket/raw_ors_data/provence/route_12717294.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_7763258.json → gs://cycle_more_bucket/raw_ors_data/provence/route_7763258.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_12509369.json → gs://cycle_more_bucket/raw_ors_data/provence/route_12509369.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13432935.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13432935.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9585794.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9585794.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_17141987.json → gs://cycle_more_bucket/raw_ors_data/provence/route_17141987.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_18652350.json → gs://cycle_more_bucket/raw_ors_data/provence/route_18652350.json
# ...
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_5146564.json → gs://cycle_more_bucket/raw_ors_data/provence/route_5146564.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_11129877.json → gs://cycle_more_bucket/raw_ors_data/provence/route_11129877.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13432896.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13432896.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_14225990.json → gs://cycle_more_bucket/raw_ors_data/provence/route_14225990.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_3975032.json → gs://cycle_more_bucket/raw_ors_data/provence/route_3975032.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_19101583.json → gs://cycle_more_bucket/raw_ors_data/provence/route_19101583.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9756608.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9756608.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_450641.json → gs://cycle_more_bucket/raw_ors_data/provence/route_450641.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_3278637.json → gs://cycle_more_bucket/raw_ors_data/provence/route_3278637.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_6881388.json → gs://cycle_more_bucket/raw_ors_data/provence/route_6881388.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_7728018.json → gs://cycle_more_bucket/raw_ors_data/provence/route_7728018.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_8611586.json → gs://cycle_more_bucket/raw_ors_data/provence/route_8611586.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13447365.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13447365.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_2808184.json → gs://cycle_more_bucket/raw_ors_data/provence/route_2808184.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_2788994.json → gs://cycle_more_bucket/raw_ors_data/provence/route_2788994.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_16731165.json → gs://cycle_more_bucket/raw_ors_data/provence/route_16731165.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_4089733.json → gs://cycle_more_bucket/raw_ors_data/provence/route_4089733.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10343139.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10343139.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_1597975.json → gs://cycle_more_bucket/raw_ors_data/provence/route_1597975.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_6132630.json → gs://cycle_more_bucket/raw_ors_data/provence/route_6132630.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_8207210.json → gs://cycle_more_bucket/raw_ors_data/provence/route_8207210.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_18782068.json → gs://cycle_more_bucket/raw_ors_data/provence/route_18782068.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10605853.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10605853.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_15974743.json → gs://cycle_more_bucket/raw_ors_data/provence/route_15974743.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_3526773.json → gs://cycle_more_bucket/raw_ors_data/provence/route_3526773.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_3971483.json → gs://cycle_more_bucket/raw_ors_data/provence/route_3971483.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9984240.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9984240.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_223801.json → gs://cycle_more_bucket/raw_ors_data/provence/route_223801.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9921672.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9921672.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10327757.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10327757.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_3255831.json → gs://cycle_more_bucket/raw_ors_data/provence/route_3255831.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10422505.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10422505.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_17675023.json → gs://cycle_more_bucket/raw_ors_data/provence/route_17675023.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_19586964.json → gs://cycle_more_bucket/raw_ors_data/provence/route_19586964.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9758026.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9758026.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_14344601.json → gs://cycle_more_bucket/raw_ors_data/provence/route_14344601.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_7241699.json → gs://cycle_more_bucket/raw_ors_data/provence/route_7241699.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_2819038.json → gs://cycle_more_bucket/raw_ors_data/provence/route_2819038.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9523609.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9523609.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_16407740.json → gs://cycle_more_bucket/raw_ors_data/provence/route_16407740.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_16011150.json → gs://cycle_more_bucket/raw_ors_data/provence/route_16011150.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_8617652.json → gs://cycle_more_bucket/raw_ors_data/provence/route_8617652.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_3278499.json → gs://cycle_more_bucket/raw_ors_data/provence/route_3278499.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10421955.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10421955.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9942127.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9942127.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_3278030.json → gs://cycle_more_bucket/raw_ors_data/provence/route_3278030.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_11560386.json → gs://cycle_more_bucket/raw_ors_data/provence/route_11560386.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10422115.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10422115.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_16794215.json → gs://cycle_more_bucket/raw_ors_data/provence/route_16794215.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_5132794.json → gs://cycle_more_bucket/raw_ors_data/provence/route_5132794.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_3977556.json → gs://cycle_more_bucket/raw_ors_data/provence/route_3977556.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_2311409.json → gs://cycle_more_bucket/raw_ors_data/provence/route_2311409.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9753104.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9753104.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_14197629.json → gs://cycle_more_bucket/raw_ors_data/provence/route_14197629.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10184282.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10184282.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13432819.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13432819.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_4089698.json → gs://cycle_more_bucket/raw_ors_data/provence/route_4089698.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10695882.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10695882.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_416295.json → gs://cycle_more_bucket/raw_ors_data/provence/route_416295.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10421996.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10421996.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10409013.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10409013.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_1532150.json → gs://cycle_more_bucket/raw_ors_data/provence/route_1532150.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_3605587.json → gs://cycle_more_bucket/raw_ors_data/provence/route_3605587.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_5994730.json → gs://cycle_more_bucket/raw_ors_data/provence/route_5994730.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9749006.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9749006.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_17751306.json → gs://cycle_more_bucket/raw_ors_data/provence/route_17751306.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13449659.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13449659.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_16492674.json → gs://cycle_more_bucket/raw_ors_data/provence/route_16492674.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10421959.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10421959.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_15577099.json → gs://cycle_more_bucket/raw_ors_data/provence/route_15577099.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_12030957.json → gs://cycle_more_bucket/raw_ors_data/provence/route_12030957.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_17055303.json → gs://cycle_more_bucket/raw_ors_data/provence/route_17055303.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9987174.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9987174.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_16741929.json → gs://cycle_more_bucket/raw_ors_data/provence/route_16741929.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13336129.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13336129.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_5148869.json → gs://cycle_more_bucket/raw_ors_data/provence/route_5148869.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_12583913.json → gs://cycle_more_bucket/raw_ors_data/provence/route_12583913.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_3841024.json → gs://cycle_more_bucket/raw_ors_data/provence/route_3841024.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_17055354.json → gs://cycle_more_bucket/raw_ors_data/provence/route_17055354.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10409770.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10409770.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_19729933.json → gs://cycle_more_bucket/raw_ors_data/provence/route_19729933.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9584949.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9584949.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_13849736.json → gs://cycle_more_bucket/raw_ors_data/provence/route_13849736.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_19783535.json → gs://cycle_more_bucket/raw_ors_data/provence/route_19783535.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10588752.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10588752.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10642911.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10642911.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_9990449.json → gs://cycle_more_bucket/raw_ors_data/provence/route_9990449.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10013401.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10013401.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_168466.json → gs://cycle_more_bucket/raw_ors_data/provence/route_168466.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10810111.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10810111.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_19849377.json → gs://cycle_more_bucket/raw_ors_data/provence/route_19849377.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_11925179.json → gs://cycle_more_bucket/raw_ors_data/provence/route_11925179.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_7564909.json → gs://cycle_more_bucket/raw_ors_data/provence/route_7564909.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_10421867.json → gs://cycle_more_bucket/raw_ors_data/provence/route_10421867.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_1752169.json → gs://cycle_more_bucket/raw_ors_data/provence/route_1752169.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_3278513.json → gs://cycle_more_bucket/raw_ors_data/provence/route_3278513.json
# Uploaded: /Users/eugeneleach/code/Eugle3/cycle_more/raw_ors_responses_Provence/route_3274926.json → gs://cycle_more_bucket/raw_ors_data/provence/route_3274926.json

# %%
import pandas as pd

# %%
df = pd.read_csv('belgium_turbo.csv')

# %%
df = df.head(2000)

# %%
df
# Out:
#           id            name  start_lon  start_lat   end_lon    end_lat  \
# 0       3770  Brialmontroute   4.467052  51.217621  4.352736  51.166423
# 1       4086   Unnamed route   4.452915  51.176121  4.440786  51.189201
# 2       4166   Unnamed route   4.462921  51.215613  4.435500  51.194407
# 3       4167   Unnamed route   4.470557  51.217474  4.498876  51.243649
# 4       4207   Unnamed route   4.435345  51.194571  4.404426  51.187413
# ...      ...             ...        ...        ...       ...        ...
# 1995  192666   Unnamed route   5.804207  50.808150  5.809477  50.790368
# 1996  192668   Unnamed route   5.768687  50.796225  5.766045  50.808316
# 1997  192670   Unnamed route   5.765028  50.795865  5.772166  50.789989
# 1998  192672   Unnamed route   5.737332  50.810978  5.732519  50.796160
# 1999  192675   Unnamed route   5.729454  50.794764  5.707791  50.796066
#
#       num_points
# 0           2076
# 1             66
# 2            256
# 3            346
# 4            192
# ...          ...
# 1995         221
# 1996         245
# 1997         142
# 1998         162
# 1999         219
#
# [2000 rows x 7 columns]
